# %% [markdown]
# ***CONNECTION*** to your google drive (code and photos should be **YOUR** Drive)

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd /content/gdrive/MyDrive/LIC/CosPlace/
# !ls
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/LIC/CosPlace
# augmentations.py  cosplace_model  LICENSE    __pycache__       trained_models
# cache		  datasets	  logs	     README.md	       train.py
# commons.py	  eval.py	  model      requirements.txt  util.py
# cosface_loss.py   hubconf.py	  parser.py  test.py

# %% [markdown]
# **INSTALLATION** of the requirements, environment probably will need to be restarted

# %%
# !pip install -r ./requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !unzip ../../dataset/processed.zip -d ../../dataset/

# %%
# !python3 train.py -h

# %% [markdown]
# ***TRAINING*** using CosPlace with ResNet50 and 2048 dim.

# %%
# !python3 train.py --dataset_folder ../../dataset/processed --backbone ResNet50 --fc_output_dim 2048 --num_workers 2 --use_amp16 --positive_dist_threshold 10 --batch_size 14 --iterations_per_epoch 500 --epochs_num 10 --min_images_per_class 5
# Out:
# 2023-03-23 12:03:25   train.py --dataset_folder ../../dataset/processed --backbone ResNet50 --fc_output_dim 2048 --num_workers 2 --use_amp16 --positive_dist_threshold 10 --batch_size 14 --iterations_per_epoch 500 --epochs_num 10 --min_images_per_class 5
# 2023-03-23 12:03:25   Arguments: Namespace(M=10, alpha=30, N=5, L=2, groups_num=8, min_images_per_class=5, backbone='ResNet50', fc_output_dim=2048, use_amp16=True, augmentation_device='cuda', batch_size=14, epochs_num=10, iterations_per_epoch=500, lr=1e-05, classifiers_lr=0.01, brightness=0.7, contrast=0.7, hue=0.5, saturation=0.7, random_resized_crop=0.5, infer_batch_size=16, positive_dist_threshold=10, resume_train=None, resume_model=None, device='cuda', seed=0, num_workers=2, dataset_folder='../../dataset/processed', save_dir='default', train_set_folder='../../dataset/processed/train', val_set_folder='../../dataset/processed/val', test_set_folder='../../dataset/processed/test')
# ...

# %%
# !ls /root/.cache/torch/hub/checkpoints/
# Out:
# resnet50-11ad3fa6.pth  ResNet50_2048_cosplace.pth

# %%
# !mv /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth ./model/ResNet50_2048_lic2.pth

# %% [markdown]
# ***EVALUATION OF THE TRAINED MODEL***

# %%
import torch
model = torch.hub.load("gmberton/cosplace", "get_trained_model", backbone="ResNet50", fc_output_dim=2048)
# !python3 eval.py --dataset_folder ../../dataset/processed --backbone ResNet50 --fc_output_dim 2048 --resume_model /root/.cache/torch/hub/checkpoints/ResNet50_2048_cosplace.pth --num_workers 2 --infer_batch_size 128 --use_amp16
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/hub.py:267: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/gmberton/cosplace/zipball/main" to /root/.cache/torch/hub/main.zip
# Returning CosPlace model with backbone: ResNet50 with features dimension 2048
# Downloading: "https://github.com/gmberton/CosPlace/releases/download/v1.0/ResNet50_2048_cosplace.pth" to /root/.cache/torch/hub/checkpoints/ResNet50_2048_cosplace.pth
# ...
