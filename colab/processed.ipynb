# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd /content/gdrive/MyDrive/LIC/lost-in-campus-2/
# !ls
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/LIC/lost-in-campus-2
# gestion-projet	README.md  requirements.txt  ressource	script

# %%
# !pip install -r ./requirements.txt

# %%
# !python3 script/main_preprocess.py -h
# Out:
# usage: argparse, args_parser.py
#        [-h]
#        [-i INPUT_FOLDER]
#        [-w NUM_WORKERS]
#        [-p CSV_POLYGON]
#        [-o OUPUT_FOLDER]
#        [-r RESET]
#        [-u UNPROCESSABLE_METHOD]
#        [-g GRID_SIZE]
#        [--height HEIGHT]
#        [--width WIDTH]
#        [--is_training IS_TRAINING]
#        [--p_training P_TRAINING]
#        [--p_val P_VAL]
#        [--p_database P_DATABASE]
#        [--shuffle SHUFFLE]
#
# Args parser
# for
# preprocess
# scripts
#
# optional arguments:
#   -h, --help
#     show this
#     help
#     message and
#     exit
#   -i INPUT_FOLDER, --input_folder INPUT_FOLDER
#     Input
#     folder of
#     raw images.
#   -w NUM_WORKERS, --num_workers NUM_WORKERS
#     Number of
#     workers for
#     scripts.
#   -p CSV_POLYGON, --csv_polygon CSV_POLYGON
#     Path to csv
#     polygon
#     file.
#   -o OUPUT_FOLDER, --ouput_folder OUPUT_FOLDER
#     Output
#     folder of
#     the
#     processed
#     images.
#   -r RESET, --reset RESET
#     Reset the p
#     reprocessin
#     g, (restart
#     from
#     scratch)
#   -u UNPROCESSABLE_METHOD, --unprocessable_method UNPROCESSABLE_METHOD
#     Method used
#     from prepro
#     cess/unproc
#     essable_ima
#     ge package
#     to deal
#     with unproc
#     essable
#     images.
#   -g GRID_SIZE, --grid_size GRID_SIZE
#     The size of
#     the grid in
#     meters for
#     the test/qu
#     eries
#   --height HEIGHT
#     Height of p
#     reprocessed
#     images.
#   --width WIDTH
#     Width of pr
#     eprocessed
#     images.
#   --is_training IS_TRAINING
#     Dataset
#     will
#     provide a
#     training
#     folder,
#     less images
#     for the
#     other
#     folders.
#   --p_training P_TRAINING
#     Percentage
#     of images
#     facing
#     north for
#     training
#     folder.
#   --p_val P_VAL
#     Percentage
#     of images
#     for
#     evaluation
#     folder, the
#     rest is for
#     test.
#   --p_database P_DATABASE
#     Percentage
#     of images
#     for
#     database
#     sub-folder
#     of test and
#     evaluation
#     folder, the
#     rest is for
#     queries.
#   --shuffle SHUFFLE
#     Shuffle the
#     organized
#     processed
#     folder,
#     ONLY
#     shuffle
#     will be
#     executed

# %%
# !python3 script/main_preprocess.py --shuffle True --o ../../dataset/processed -w 16 -p script/polygon.csv -g 10
# Out:
# {'input_folder': PosixPath('dataset'), 'num_workers': 16, 'csv_polygon': PosixPath('script/polygon.csv'), 'ouput_folder': PosixPath('../../dataset/processed'), 'reset': False, 'unprocessable_method': <function change_suffix at 0x7ffacbabd0d0>, 'grid_size': 10, 'height': 512, 'width': 512, 'is_training': True, 'p_training': 0.85, 'p_val': 0.15, 'p_database': 0.8, 'shuffle': True}
# Organizing images: 100% 19500/19500 [23:04<00:00, 14.09image/s]
# -- Oragnized Tree : --
# .
# └── processed
#    └── train  : 4714
#    └── val  : 2152
#       ├── database  : 1761
#       └── queries  : **/ 391
#    └── test  : 12634
#       ├── database  : 10082
#       └── queries  : **/ 2552
#
# Figure(640x480)
# Figure(640x480)
